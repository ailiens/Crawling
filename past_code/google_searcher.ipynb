# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def google_search(query, num_results):
    search_results = []
    query = query.replace(' ', '+')
    url = f"https://www.google.com/search?q={query}&num={num_results}"

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
    }

    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        result_divs = soup.find_all('div', class_='g')

        for result in result_divs:
            title = result.find('h3')
            link = result.find('a')
            if title and link:
                site_name = title.text
                site_url = link['href']
                search_results.append({'Site Name': site_name, 'URL': site_url})
                print(f"Collected: Site Name: {site_name}, URL: {site_url}")  # 중간 결과 출력
            if len(search_results) >= num_results:
                break
    else:
        print(f"Failed to retrieve search results. Status code: {response.status_code}")

    return search_results

def save_to_excel(results, filename):
    df = pd.DataFrame(results)
    df.to_excel(filename, index=False)
    print(f"Results saved to {filename}")

if __name__ == "__main__":
    query = "알파브라더스"
    num_results = 50
    results = google_search(query, num_results)
    save_to_excel(results, "google_search_results.xlsx")
# Out:
# Collected: Site Name: 알파브라더스, URL: https://www.alphabrothers.co.kr/
# Collected: Site Name: 알파브라더스, URL: https://www.alphabrothers.co.kr/
# Collected: Site Name: (주)알파브라더스 2024년 기업정보 | 직원수, 근무환경, 복리 ..., URL: https://www.saramin.co.kr/zf_user/company-info/view/csn/ZU5FRU9NTCtSdkJNM2NJdEpYcmVadz09/company_nm/(%EC%A3%BC)%EC%95%8C%ED%8C%8C%EB%B8%8C%EB%9D%BC%EB%8D%94%EC%8A%A4
# Collected: Site Name: (주)알파브라더스 2024년 상반기 채용, URL: https://www.jobplanet.co.kr/companies/377540/reviews/%EC%95%8C%ED%8C%8C%EB%B8%8C%EB%9D%BC%EB%8D%94%EC%8A%A4
# Collected: Site Name: 주식회사 알파브라더스, URL: https://www.rocketpunch.com/companies/alphabrothers
# Collected: Site Name: 알파브라더스, URL: https://abvoucher.com/
# Collected: Site Name: ABBG - 국내 1위 디자인 구독 에이전시, URL: https://abbg.co.kr/
# Collected: Site Name: 알파브라더스 기업정보 - 평균연봉 3063만원, 인원 63명, ..., URL: https://www.wanted.co.kr/company/8607
# Collected: Site Name: 2024년 알파브라더스 채용 기업정보, URL: https://www.incruit.com/company/1680769893/
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def google_search(query, num_results):
    search_results = []
    query = query.replace(' ', '+')
    url = f"https://www.google.com/search?q={query}&num={num_results}"

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
    }

    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        result_divs = soup.find_all('div', class_='g')

        for result in result_divs:
            title = result.find('h3')
            link = result.find('a')
            if title and link:
                site_name = title.text
                site_url = link['href']
                search_results.append({'Site Name': site_name, 'URL': site_url})
                print(f"Collected: Site Name: {site_name}, URL: {site_url}")  # 중간 결과 출력
            if len(search_results) >= num_results:
                break
    else:
        print(f"Failed to retrieve search results. Status code: {response.status_code}")

    return search_results

def save_to_excel(results, filename):
    df = pd.DataFrame(results)
    df.to_excel(filename, index=False)
    print(f"Results saved to {filename}")

def filter_and_save_urls(input_filename, output_filename, keywords):
    df = pd.read_excel(input_filename)
    keyword_regex = '|'.join(keywords)
    filtered_df = df[df['URL'].str.contains(keyword_regex, case=False, na=False)]
    filtered_df.to_excel(output_filename, index=False)
    print(f"Filtered results saved to {output_filename}")

if __name__ == "__main__":
    query = "알파브라더스"
    query_2 = "ABBG"
    query_3 = "ABDG"
    query_4 = "그로스파트너"
    query_5 = "12pm studio"
    num_results = 50
    results = google_search(query, num_results)
    excel_filename = "google_search_results.xlsx"
    save_to_excel(results, excel_filename)

    keywords = ['instagram', 'facebook', 'naver', 'youtube']
    filtered_excel_filename = "filtered_google_search_results.xlsx"
    filter_and_save_urls(excel_filename, filtered_excel_filename, keywords)
# Out:
# Collected: Site Name: ABBG - 국내 1위 디자인 구독 에이전시, URL: https://abbg.co.kr/
# Collected: Site Name: ABBG - 국내 1위 디자인 구독 에이전시, URL: https://abbg.co.kr/
# Collected: Site Name: 디자인 구독 추천 낮은 외주비용으로 10명 팀 만드는 ABBG, URL: https://blog.naver.com/joinjaang/223464706843?fromRss=true&trackingCode=rss
# Collected: Site Name: ABBG, URL: https://americanbusbenchmarking.org/
# Collected: Site Name: [ABBG] 새로운 회사에 입사하며 어떤 기대와 두려움이 있었나요 ..., URL: https://www.youtube.com/watch?v=NJ23OKKx4zU
# Collected: Site Name: 디자이너드벤처 by ABBG, URL: https://m.youtube.com/@designerdventure
# Collected: Site Name: [어크루] 마르셀 Marcel ABBG, URL: https://totalsun.co.kr/product/%EC%96%B4%ED%81%AC%EB%A3%A8-%EB%A7%88%EB%A5%B4%EC%85%80-marcel-abbg/3140/
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def google_search(query, num_results):
    search_results = []
    query = query.replace(' ', '+')
    url = f"https://www.google.com/search?q={query}&num={num_results}"

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
    }

    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        result_divs = soup.find_all('div', class_='g')

        for result in result_divs:
            title = result.find('h3')
            link = result.find('a')
            if title and link:
                site_name = title.text
                site_url = link['href']
                search_results.append({'Site Name': site_name, 'URL': site_url})
                print(f"Collected: Site Name: {site_name}, URL: {site_url}")  # 중간 결과 출력
            if len(search_results) >= num_results:
                break
    else:
        print(f"Failed to retrieve search results. Status code: {response.status_code}")

    return search_results

def save_to_excel(results, filename):
    df = pd.DataFrame(results)
    df.to_excel(filename, index=False)
    print(f"Results saved to {filename}")

def filter_and_save_urls(input_filename, output_filename, keywords):
    df = pd.read_excel(input_filename)
    keyword_regex = '|'.join(keywords)
    filtered_df = df[df['URL'].str.contains(keyword_regex, case=False, na=False)]
    filtered_df.to_excel(output_filename, index=False)
    print(f"Filtered results saved to {output_filename}")

def process_query(query, num_results, keywords):
    results = google_search(query, num_results)
    query_filename = query.replace(' ', '_')
    excel_filename = f"google_search_results_{query_filename}.xlsx"
    save_to_excel(results, excel_filename)
    filtered_excel_filename = f"filtered_google_search_results_{query_filename}.xlsx"
    filter_and_save_urls(excel_filename, filtered_excel_filename, keywords)

if __name__ == "__main__":
    num_results = 50
    keywords = ['instagram', 'facebook', 'naver', 'youtube', 'twitter']
    queries = ["알파브라더스", "ABBG", "ABDG", "그로스파트너", "12pm studio"]
    
    for query in queries:
        process_query(query, num_results, keywords)
# Out:
# Collected: Site Name: 알파브라더스, URL: https://www.alphabrothers.co.kr/
# Collected: Site Name: 알파브라더스, URL: https://www.alphabrothers.co.kr/
# Collected: Site Name: (주)알파브라더스 2024년 기업정보 | 직원수, 근무환경, 복리 ..., URL: https://www.saramin.co.kr/zf_user/company-info/view/csn/ZU5FRU9NTCtSdkJNM2NJdEpYcmVadz09/company_nm/(%EC%A3%BC)%EC%95%8C%ED%8C%8C%EB%B8%8C%EB%9D%BC%EB%8D%94%EC%8A%A4
# Collected: Site Name: (주)알파브라더스 2024년 상반기 채용, URL: https://www.jobplanet.co.kr/companies/377540/reviews/%EC%95%8C%ED%8C%8C%EB%B8%8C%EB%9D%BC%EB%8D%94%EC%8A%A4
# Collected: Site Name: 주식회사 알파브라더스, URL: https://www.rocketpunch.com/companies/alphabrothers
# Collected: Site Name: 알파브라더스, URL: https://abvoucher.com/
# Collected: Site Name: ABBG - 국내 1위 디자인 구독 에이전시, URL: https://abbg.co.kr/
# Collected: Site Name: 알파브라더스 기업정보 - 평균연봉 3063만원, 인원 63명, ..., URL: https://www.wanted.co.kr/company/8607
# Collected: Site Name: 2024년 알파브라더스 채용 기업정보, URL: https://www.incruit.com/company/1680769893/
# ...

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import pandas as pd

def get_search_results(url, num_results):
    # Selenium 웹 드라이버 설정
    driver = webdriver.Chrome()  # 또는 webdriver.Firefox() 등
    driver.get(url)
    time.sleep(5)  # 페이지 로드 대기

    # BeautifulSoup으로 페이지 소스 파싱
    soup = BeautifulSoup(driver.page_source, 'html.parser')

    search_results = []
    videos = soup.find_all('ytd-video-renderer', class_='style-scope ytd-item-section-renderer')
    
    for video in videos:
        title_tag = video.find('a', id='video-title')
        channel_tag = video.find('a', class_='yt-simple-endpoint style-scope yt-formatted-string')
        if title_tag and channel_tag:
            title = title_tag.get_text(strip=True)
            channel_name = channel_tag.get_text(strip=True)
            search_results.append({'Title': title, 'Channel Name': channel_name})
            print(f"Collected: Title: {title}, Channel Name: {channel_name}")  # 중간 결과 출력
        if len(search_results) >= num_results:
            break

    driver.quit()
    return search_results

def save_to_excel(data, filename):
    df = pd.DataFrame(data)
    df.to_excel(filename, index=False)
    print(f"Results saved to {filename}")

if __name__ == "__main__":
    search_query = "알파브라더스"
    search_url = f'https://www.youtube.com/results?search_query={search_query}'
    num_results = 30  # 원하는 검색 결과 수

    video_details = get_search_results(search_url, num_results)
    excel_filename = f'youtube_search_results_{search_query.replace(" ", "_")}.xlsx'
    save_to_excel(video_details, excel_filename)
# Out:
# Collected: Title: 알파브라더스 회사소개 모션그래픽 영상 입니다., Channel Name: alphabrothers
# Collected: Title: 취업뉴비를 도와주는 경영 길잡이 '취슐랭가이드 알파브라더스', Channel Name: 취슐랭 가이드 - 서울취업맛집 소개
# Collected: Title: SBA X 크몽 | 후속 자금조달에 추진력을 얻는 방법 by 알파브라더스 이보름 투자심사역, Channel Name: ss.up.tv(썹tv) 서울창업허브
# Collected: Title: 알파 브라더스 채용 브랜딩, Channel Name: 또부치
# Collected: Title: [모션그래픽/홍보영상] 티몬_타이포모션, Channel Name: 알파브라더스 ALPHA BROTHERS ARCHIVE
# Collected: Title: 알파브라더스 스타트업컨설팅, Channel Name: alphabrothers
# Collected: Title: [모션그래픽/제품영상] 라올바이오_홍보영상(국문), Channel Name: 알파브라더스 ALPHA BROTHERS ARCHIVE
# Collected: Title: [인포그래픽/광고영상] 우리아이들병원, Channel Name: 알파브라더스 ALPHA BROTHERS ARCHIVE
# Collected: Title: 알파브라더스 채용브랜딩, Channel Name: 또부치
# Collected: Title: 알파브라더스 브랜드 광고영상, Channel Name: alphabrothers
# Collected: Title: [모션그래픽/유튜브타이틀] 따지는TV_Tile_PKG, Channel Name: 알파브라더스 ALPHA BROTHERS ARCHIVE
# Collected: Title: 아나운서 퇴출된 방송사고14, Channel Name: 시간순삭s
# ...

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import pandas as pd

def get_search_results(url, num_results, search_query, scroll_pause_time=2):
    # Selenium 웹 드라이버 설정
    driver = webdriver.Chrome()  # 또는 webdriver.Firefox() 등
    driver.get(url)
    time.sleep(5)  # 페이지 로드 대기

    # 페이지를 스크롤하여 더 많은 결과 로드
    last_height = driver.execute_script("return document.documentElement.scrollHeight")

    search_results = []

    while len(search_results) < num_results:
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        videos = soup.find_all('ytd-video-renderer', class_='style-scope ytd-item-section-renderer')
        
        for video in videos:
            title_tag = video.find('a', id='video-title')
            channel_tag = video.find('a', class_='yt-simple-endpoint style-scope yt-formatted-string')
            if title_tag and channel_tag:
                title = title_tag.get_text(strip=True)
                channel_name = channel_tag.get_text(strip=True)
                if search_query.lower() in title.lower():  # 검색 쿼리가 제목에 포함되어 있는지 확인
                    search_results.append({'Title': title, 'Channel Name': channel_name})
                    print(f"Collected: Title: {title}, Channel Name: {channel_name}")  # 중간 결과 출력
            if len(search_results) >= num_results:
                break
        
        if len(search_results) >= num_results:
            break

        # 더 많은 결과를 로드하기 위해 스크롤
        driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
        time.sleep(scroll_pause_time)  # 스크롤 후 로드 대기

        new_height = driver.execute_script("return document.documentElement.scrollHeight")
        if new_height == last_height:
            break  # 더 이상 로드할 결과가 없음
        last_height = new_height

    driver.quit()
    return search_results[:num_results]  # 정확히 num_results 만큼만 반환

def save_to_excel(data, filename):
    df = pd.DataFrame(data)
    df.to_excel(filename, index=False)
    print(f"Results saved to {filename}")

if __name__ == "__main__":
    search_query = "알파브라더스"
    search_url = f'https://www.youtube.com/results?search_query={search_query}'
    num_results = 50  # 원하는 검색 결과 수

    video_details = get_search_results(search_url, num_results, search_query)
    excel_filename = f'youtube_search_results_{search_query.replace(" ", "_")}.xlsx'
    save_to_excel(video_details, excel_filename)
# Out:
# Collected: Title: 알파브라더스 회사소개 모션그래픽 영상 입니다., Channel Name: alphabrothers
# Collected: Title: 취업뉴비를 도와주는 경영 길잡이 '취슐랭가이드 알파브라더스', Channel Name: 취슐랭 가이드 - 서울취업맛집 소개
# Collected: Title: SBA X 크몽 | 후속 자금조달에 추진력을 얻는 방법 by 알파브라더스 이보름 투자심사역, Channel Name: ss.up.tv(썹tv) 서울창업허브
# Collected: Title: 알파브라더스 스타트업컨설팅, Channel Name: alphabrothers
# Collected: Title: 알파브라더스 채용브랜딩, Channel Name: 또부치
# Collected: Title: 알파브라더스 브랜드 광고영상, Channel Name: alphabrothers
# Collected: Title: 알파브라더스 브랜딩 영상, Channel Name: alphabrothers
# Collected: Title: 알파브라더스 회사소개 모션그래픽 영상 입니다., Channel Name: alphabrothers
# Collected: Title: 취업뉴비를 도와주는 경영 길잡이 '취슐랭가이드 알파브라더스', Channel Name: 취슐랭 가이드 - 서울취업맛집 소개
# Collected: Title: SBA X 크몽 | 후속 자금조달에 추진력을 얻는 방법 by 알파브라더스 이보름 투자심사역, Channel Name: ss.up.tv(썹tv) 서울창업허브
# Collected: Title: 알파브라더스 스타트업컨설팅, Channel Name: alphabrothers
# Collected: Title: 알파브라더스 채용브랜딩, Channel Name: 또부치
# Collected: Title: 알파브라더스 브랜드 광고영상, Channel Name: alphabrothers
# ...

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import pandas as pd

def get_search_results(url, num_results, scroll_pause_time=2):
    # Selenium 웹 드라이버 설정
    driver = webdriver.Chrome()  # 또는 webdriver.Firefox() 등
    driver.get(url)
    time.sleep(5)  # 페이지 로드 대기

    # 페이지를 스크롤하여 더 많은 결과 로드
    last_height = driver.execute_script("return document.documentElement.scrollHeight")

    search_results = []

    while len(search_results) < num_results:
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        videos = soup.find_all('ytd-video-renderer', class_='style-scope ytd-item-section-renderer')
        
        for video in videos:
            title_tag = video.find('a', id='video-title')
            channel_tag = video.find('a', class_='yt-simple-endpoint style-scope yt-formatted-string')
            if title_tag and channel_tag:
                title = title_tag.get_text(strip=True)
                channel_name = channel_tag.get_text(strip=True)
                search_results.append({'Title': title, 'Channel Name': channel_name})
                print(f"Collected: Title: {title}, Channel Name: {channel_name}")  # 중간 결과 출력
            if len(search_results) >= num_results:
                break
        
        if len(search_results) >= num_results:
            break

        # 더 많은 결과를 로드하기 위해 스크롤
        driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
        time.sleep(scroll_pause_time)  # 스크롤 후 로드 대기

        new_height = driver.execute_script("return document.documentElement.scrollHeight")
        if new_height == last_height:
            break  # 더 이상 로드할 결과가 없음
        last_height = new_height

    driver.quit()
    return search_results

def filter_results(results, keyword):
    keyword_lower = keyword.lower()
    filtered_results = [result for result in results if keyword_lower in result['Title'].lower() or keyword_lower in result['Channel Name'].lower()]
    return filtered_results

def save_to_excel(data, filename):
    df = pd.DataFrame(data)
    df.to_excel(filename, index=False)
    print(f"Results saved to {filename}")

if __name__ == "__main__":
    search_query = "알파브라더스"
    search_query2 = "ABBG"
    search_query3 = "ABDG"
    search_query4 = "그로스파트너"
    search_query5 = "12pm studio"
    
    search_url = f'https://www.youtube.com/results?search_query={search_query}'
    num_results = 50  # 원하는 검색 결과 수

    video_details = get_search_results(search_url, num_results)
    filtered_video_details = filter_results(video_details, search_query)
    excel_filename = f'youtube_search_results_{search_query.replace(" ", "_")}.xlsx'
    save_to_excel(filtered_video_details, excel_filename)
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[47], line 68
#      65 search_url = f'https://www.youtube.com/results?search_query={search_query}'
#      66 num_results = 50  # 원하는 검색 결과 수
# ---> 68 video_details = get_search_results(search_url, num_results)
#      69 filtered_video_details = filter_results(video_details, search_query)
#      70 excel_filename = f'youtube_search_results_{search_query.replace(" ", "_")}.xlsx'
#
# Cell In[47], line 14, in get_search_results(url, num_results, scroll_pause_time)
#      11 time.sleep(5)  # 페이지 로드 대기
#      13 # 페이지를 스크롤하여 더 많은 결과 로드
# ---> 14 last_height = driver.execute_script("return document.documentElement.scrollHeight")
#      16 search_results = []
#      18 while len(search_results) < num_results:
#
# ...

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import pandas as pd

def get_search_results(url, num_results, scroll_pause_time=2):
    # Selenium 웹 드라이버 설정
    driver = webdriver.Chrome()  # 또는 webdriver.Firefox() 등
    driver.get(url)
    time.sleep(5)  # 페이지 로드 대기

    # 페이지를 스크롤하여 더 많은 결과 로드
    last_height = driver.execute_script("return document.documentElement.scrollHeight")

    search_results = []

    while len(search_results) < num_results:
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        videos = soup.find_all('ytd-video-renderer', class_='style-scope ytd-item-section-renderer')
        
        for video in videos:
            title_tag = video.find('a', id='video-title')
            channel_tag = video.find('a', class_='yt-simple-endpoint style-scope yt-formatted-string')
            if title_tag and channel_tag:
                title = title_tag.get_text(strip=True)
                channel_name = channel_tag.get_text(strip=True)
                search_results.append({'Title': title, 'Channel Name': channel_name})
                print(f"Collected: Title: {title}, Channel Name: {channel_name}")  # 중간 결과 출력
            if len(search_results) >= num_results:
                break
        
        if len(search_results) >= num_results:
            break

        # 더 많은 결과를 로드하기 위해 스크롤
        driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
        time.sleep(scroll_pause_time)  # 스크롤 후 로드 대기

        new_height = driver.execute_script("return document.documentElement.scrollHeight")
        if new_height == last_height:
            break  # 더 이상 로드할 결과가 없음
        last_height = new_height

    driver.quit()
    return search_results

def filter_results(results, keyword):
    keyword_lower = keyword.lower()
    filtered_results = [result for result in results if keyword_lower in result['Title'].lower() or keyword_lower in result['Channel Name'].lower()]
    return filtered_results

def save_to_excel(data, filename):
    df = pd.DataFrame(data)
    df.to_excel(filename, index=False)
    print(f"Results saved to {filename}")

def process_search_query(search_query, num_results):
    search_url = f'https://www.youtube.com/results?search_query={search_query}'
    video_details = get_search_results(search_url, num_results)
    filtered_video_details = filter_results(video_details, search_query)
    excel_filename = f'youtube_search_results_{search_query.replace(" ", "_")}.xlsx'
    save_to_excel(filtered_video_details, excel_filename)

if __name__ == "__main__":
    search_queries = ["알파브라더스", "ABBG", "ABDG", "그로스파트너", "12pm 스튜디오"]
    num_results = 50  # 원하는 검색 결과 수

    for query in search_queries:
        process_search_query(query, num_results)
# Out:
# Collected: Title: 알파브라더스 회사소개 모션그래픽 영상 입니다., Channel Name: alphabrothers
# Collected: Title: 취업뉴비를 도와주는 경영 길잡이 '취슐랭가이드 알파브라더스', Channel Name: 취슐랭 가이드 - 서울취업맛집 소개
# Collected: Title: SBA X 크몽 | 후속 자금조달에 추진력을 얻는 방법 by 알파브라더스 이보름 투자심사역, Channel Name: ss.up.tv(썹tv) 서울창업허브
# Collected: Title: 알파 브라더스 채용 브랜딩, Channel Name: 또부치
# Collected: Title: 중국판 플스 사보기 ㅋㅋㅋ, Channel Name: 절대멘탈
# Collected: Title: [모션그래픽/홍보영상] 티몬_타이포모션, Channel Name: 알파브라더스 ALPHA BROTHERS ARCHIVE
# Collected: Title: 알파브라더스 스타트업컨설팅, Channel Name: alphabrothers
# Collected: Title: [모션그래픽/제품영상] 라올바이오_제품영상(국문), Channel Name: 알파브라더스 ALPHA BROTHERS ARCHIVE
# Collected: Title: [모션그래픽/제품영상] 라올바이오_홍보영상(국문), Channel Name: 알파브라더스 ALPHA BROTHERS ARCHIVE
# Collected: Title: 카베르네소비뇽 Cabernet Sauvignon, 같은품종 다른느낌 4종 국가별 비교 테이스팅ㅣ품종별 취향찾기, Channel Name: 진스 와인페어링 Jin's WinePairing
# Collected: Title: 알파브라더스 채용브랜딩, Channel Name: 또부치
# Collected: Title: 알파브라더스 브랜드 광고영상, Channel Name: alphabrothers
# ...
